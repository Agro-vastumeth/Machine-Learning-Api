# %%
import pandas as pd
import numpy as np
import os
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('elemental.csv')

# %%
df.head()
# Out:
#    Seial No.      C     H       N       O   Ash  practicle estimate  \
# 0          1  41.00  5.400  0.740  36.860  16.0                 450
# 1          2  35.20  5.596  0.745  39.959  18.5                 523
# 2          3  40.83  5.800  0.800  39.340   NaN                 589
# 3          4  41.50  6.700  0.800  41.200   NaN                 756
# 4          5  42.20  6.000  0.800  38.700   NaN                 521
#
#    Emp(C)(a)  Emp(C) a  Emp(H) b  Emp(N)(d)  Emp(O) (c)       TMP  \
# 0   3.416667         1  1.580488   0.216585   10.788293 -0.246312
# 1   2.933333         1  1.907727   0.253977   13.622386 -0.262835
# 2   3.402500         1  1.704629   0.235121   11.562087 -0.251249
# 3   3.458333         1  1.937349   0.231325   11.913253 -0.250413
# 4   3.516667         1  1.706161   0.227488   11.004739 -0.246468
#
#                                              Process  Unnamed: 14  \
# 0  The spe-cific methane and biogas production yi...          NaN
# ...

# %%
df.dropna(axis=1, )
